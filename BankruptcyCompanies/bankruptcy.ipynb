# %%
import pandas as pd
import numpy as np
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK
from pyecharts import options as opts
from pyecharts.charts import Map, Bar, Line, Timeline, Pie
from pyecharts.components import Table
from pyecharts.options import ComponentTitleOpts
from pyecharts.faker import Faker

# %%
# 这是一份来自和鲸社区的倒闭企业数据集，总计 6,272 条记录，大小为 2.3 M，包含 21 个字段。
data = pd.read_csv("com.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6272 entries, 0 to 6271
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   bianh         6272 non-null   int64
#  1   com_name      6272 non-null   object
#  2   com_addr      6272 non-null   object
#  3   cat           6272 non-null   object
#  4   se_cat        6271 non-null   object
#  5   com_des       6271 non-null   object
#  6   born_data     6272 non-null   object
#  7   death_data    6272 non-null   object
#  8   live_days     6272 non-null   int64
#  9   financing     6272 non-null   object
#  10  total_money   805 non-null    float64
#  11  death_reason  1419 non-null   object
#  12  invest_name   600 non-null    object
#  13  ceo_name      4839 non-null   object
#  14  ceo_des       4838 non-null   object
#  15  ceo_per_des   4839 non-null   object
#  16  Unnamed: 16   0 non-null      float64
#  17  Unnamed: 17   0 non-null      float64
#  18  Unnamed: 18   0 non-null      float64
#  19  Unnamed: 19   0 non-null      float64
#  20  Unnamed: 20   0 non-null      float64
# dtypes: float64(6), int64(2), object(13)
# memory usage: 1.0+ MB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# 倒闭公司的地区分布
data["com_addr"] =  data["com_addr"].str.strip()

dict = data.groupby("com_addr").size().to_dict()

# dict

map = (
    Map()
    .add("倒闭公司数量",[*dict.items()], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="地区分布"),
        visualmap_opts = opts.VisualMapOpts(max_=200),
    )
)

map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="17c259564825457ba3d6cf08f9788b4e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_17c259564825457ba3d6cf08f9788b4e = echarts.init(
#                     document.getElementById('17c259564825457ba3d6cf08f9788b4e'), 'white', {renderer: 'canvas'});
#                 var option_17c259564825457ba3d6cf08f9788b4e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5012\u95ed\u516c\u53f8\u6570\u91cf",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "map": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 1034
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u4e9a\u6d32",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 2239
#                 },
#                 {
#                     "name": "\u5317\u7f8e\u6d32",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 282
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1095
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6b27\u6d32",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 253
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 395
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 117
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 140
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 72
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 79
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 17
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "zlevel": 0,
#             "z": 2,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5012\u95ed\u516c\u53f8\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u5730\u533a\u5206\u5e03",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",

# %%
# 行业排行top10
category = data.groupby("cat").size().sort_values(ascending=False)[:10]

dict = category.to_dict()

bar = (
    Bar()
    .add_xaxis([*dict.keys()])
    .add_yaxis("倒闭数量",[*dict.values()], label_opts = opts.LabelOpts(position="top"))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="行业排行top10"),
    )
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e55235c51e844dbbb2548bfc4a7ad061" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e55235c51e844dbbb2548bfc4a7ad061 = echarts.init(
#                     document.getElementById('e55235c51e844dbbb2548bfc4a7ad061'), 'white', {renderer: 'canvas'});
#                 var option_e55235c51e844dbbb2548bfc4a7ad061 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5012\u95ed\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 925,
#                 789,
#                 595,
#                 510,
#                 500,
#                 421,
#                 376,
#                 374,
#                 334,
#                 311
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5012\u95ed\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7535\u5b50\u5546\u52a1",
#                 "\u4f01\u4e1a\u670d\u52a1",
#                 "\u672c\u5730\u751f\u6d3b",
#                 "\u91d1\u878d",
#                 "\u793e\u4ea4\u7f51\u7edc",
#                 "\u6587\u5a31\u4f20\u5a92",
#                 "\u6559\u80b2",
#                 "\u5de5\u5177\u8f6f\u4ef6",
#                 "\u6e38\u620f",
#                 "\u6c7d\u8f66\u4ea4\u901a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u884c\u4e1a\u6392\u884ctop10",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_e55235c51e844dbbb2548bfc4a7ad061.setOption(option_e55235c51e844dbbb2548bfc4a7ad061);
#         });
#     </script>

# %%
# 细分领域top20
secondary_category = data.groupby("se_cat").size().sort_values(ascending=False)[:20].sort_values()

dict = secondary_category.to_dict()

bar = (
    Bar()
    .add_xaxis([*dict.keys()])
    .add_yaxis("倒闭数量",[*dict.values()], label_opts = opts.LabelOpts(position="right"))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="行业排行top10"),
    )
    .reversal_axis()
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d01bc164075b45e9b830d94b618bf55b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d01bc164075b45e9b830d94b618bf55b = echarts.init(
#                     document.getElementById('d01bc164075b45e9b830d94b618bf55b'), 'white', {renderer: 'canvas'});
#                 var option_d01bc164075b45e9b830d94b618bf55b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5012\u95ed\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 83,
#                 91,
#                 95,
#                 100,
#                 103,
#                 110,
#                 111,
#                 112,
#                 119,
#                 119,
#                 120,
#                 124,
#                 129,
#                 136,
#                 139,
#                 145,
#                 149,
#                 162,
#                 224,
#                 240
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5012\u95ed\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u513f\u7ae5\u65e9\u6559",
#                 "\u4e8b\u9879\u53ca\u6548\u7387",
#                 "\u5176\u4ed6\u7535\u5546\u670d\u52a1",
#                 "\u4ea4\u901a\u51fa\u884c",
#                 "\u6574\u5408\u8425\u9500\u4f20\u64ad",
#                 "\u7406\u8d22",
#                 "\u670d\u88c5\u670d\u9970",
#                 "\u5a92\u4f53\u53ca\u9605\u8bfb",
#                 "\u751f\u9c9c\u98df\u54c1",
#                 "\u964c\u751f\u4eba\u4ea4\u53cb",
#                 "\u5176\u4ed6\u4f01\u4e1a\u670d\u52a1",
#                 "\u672c\u5730\u7efc\u5408\u751f\u6d3b",
#                 "\u4eba\u529b\u8d44\u6e90",
#                 "\u7535\u5546\u89e3\u51b3\u65b9\u6848",
#                 "\u5174\u8da3\u793e\u533a",
#                 "\u884c\u4e1a\u4fe1\u606f\u5316\u53ca\u89e3\u51b3\u65b9\u6848",
#                 "\u501f\u8d37",
#                 "\u7f8e\u98df\u9910\u996e",
#                 "\u7efc\u5408\u7535\u5546",
#                 "\u6e38\u620f\u5f00\u53d1\u5546"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u884c\u4e1a\u6392\u884ctop10",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_d01bc164075b45e9b830d94b618bf55b.setOption(option_d01bc164075b45e9b830d94b618bf55b);
#         });
#     </script>

# %%
# 年份分布
data["born_data"] = pd.to_datetime(data["born_data"])
data["death_data"] = pd.to_datetime(data["death_data"])

data.rename({"born_data":"born_date","death_data":"death_date"}, axis=1, inplace=True)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6272 entries, 0 to 6271
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   bianh         6272 non-null   int64
#  1   com_name      6272 non-null   object
#  2   com_addr      6272 non-null   object
#  3   cat           6272 non-null   object
#  4   se_cat        6271 non-null   object
#  5   com_des       6271 non-null   object
#  6   born_date     6272 non-null   datetime64[ns]
#  7   death_date    6272 non-null   datetime64[ns]
#  8   live_days     6272 non-null   int64
#  9   financing     6272 non-null   object
#  10  total_money   805 non-null    float64
#  11  death_reason  1419 non-null   object
#  12  invest_name   600 non-null    object
#  13  ceo_name      4839 non-null   object
#  14  ceo_des       4838 non-null   object
#  15  ceo_per_des   4839 non-null   object
#  16  Unnamed: 16   0 non-null      float64
#  17  Unnamed: 17   0 non-null      float64
#  18  Unnamed: 18   0 non-null      float64
#  19  Unnamed: 19   0 non-null      float64
#  20  Unnamed: 20   0 non-null      float64
# dtypes: datetime64[ns](2), float64(6), int64(2), object(11)
# memory usage: 1.0+ MB

# %%
born_com = data.groupby(data["born_date"].dt.year).size().to_dict()
dead_com = data.groupby(data["death_date"].dt.year).size().to_dict()

# merge 2 df
df1 = pd.DataFrame({"year": born_com.keys(), "born": born_com.values()})
df2 = pd.DataFrame({"year": dead_com.keys(), "dead": dead_com.values()})

df = pd.merge(df1, df2, on="year")

df =  df[df["year"].astype("str") > "2008"].reset_index(drop=True).sort_values(by="year")

# df

bar = (
    Bar()
    .add_xaxis(list(df["year"]))
    .add_yaxis("新成立企业数",list(df["born"]),label_opts = opts.LabelOpts(position="top"))
    .add_yaxis("倒闭企业数",list(df["dead"]), label_opts = opts.LabelOpts(position="top"))
    .set_global_opts(title_opts=opts.TitleOpts(title="年份分布"))
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="71cb26c21b1e488999e4e74c744db689" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_71cb26c21b1e488999e4e74c744db689 = echarts.init(
#                     document.getElementById('71cb26c21b1e488999e4e74c744db689'), 'white', {renderer: 'canvas'});
#                 var option_71cb26c21b1e488999e4e74c744db689 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u65b0\u6210\u7acb\u4f01\u4e1a\u6570",
#             "legendHoverLink": true,
#             "data": [
#                 164,
#                 268,
#                 583,
#                 940,
#                 1341,
#                 1410,
#                 944,
#                 252,
#                 34,
#                 6,
#                 1
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5012\u95ed\u4f01\u4e1a\u6570",
#             "legendHoverLink": true,
#             "data": [
#                 25,
#                 40,
#                 57,
#                 70,
#                 182,
#                 335,
#                 1131,
#                 1458,
#                 2145,
#                 458,
#                 327
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u65b0\u6210\u7acb\u4f01\u4e1a\u6570",
#                 "\u5012\u95ed\u4f01\u4e1a\u6570"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 2009,
#                 2010,
#                 2011,
#                 2012,
#                 2013,
#                 2014,
#                 2015,
#                 2016,
#                 2017,
#                 2018,
#                 2019
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u5e74\u4efd\u5206\u5e03",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_71cb26c21b1e488999e4e74c744db689.setOption(option_71cb26c21b1e488999e4e74c744db689);
#         });
#     </script>

# %%
# 企业存活时间
# data.info()

def live_year(x):
    if x < 365:
        return '不到1年'
    if x < 365 * 2:
        return '1-2年'
    if x < 365 * 3:
        return '2-3年'
    if x < 365 * 4:
        return '3-4年'
    if x < 365 * 5:
        return '4-5年'
    if x < 365 * 10:
        return '5-10年'
    return '10年以上'

s = data.groupby(data['live_days'].apply(lambda x: live_year(x))).size()

pie = (
    Pie()
    .add("企业存活时间",[*s.items()])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c} ({d}%)"))
)

pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ac45108173e8488db7619c4c1a58280d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ac45108173e8488db7619c4c1a58280d = echarts.init(
#                     document.getElementById('ac45108173e8488db7619c4c1a58280d'), 'white', {renderer: 'canvas'});
#                 var option_ac45108173e8488db7619c4c1a58280d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u4f01\u4e1a\u5b58\u6d3b\u65f6\u95f4",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "1-2\u5e74",
#                     "value": 644
#                 },
#                 {
#                     "name": "10\u5e74\u4ee5\u4e0a",
#                     "value": 60
#                 },
#                 {
#                     "name": "2-3\u5e74",
#                     "value": 2242
#                 },
#                 {
#                     "name": "3-4\u5e74",
#                     "value": 1108
#                 },
#                 {
#                     "name": "4-5\u5e74",
#                     "value": 954
#                 },
#                 {
#                     "name": "5-10\u5e74",
#                     "value": 1219
#                 },
#                 {
#                     "name": "\u4e0d\u52301\u5e74",
#                     "value": 45
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c} ({d}%)"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1-2\u5e74",
#                 "10\u5e74\u4ee5\u4e0a",
#                 "2-3\u5e74",
#                 "3-4\u5e74",
#                 "4-5\u5e74",
#                 "5-10\u5e74",
#                 "\u4e0d\u52301\u5e74"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     }
# };
#                 chart_ac45108173e8488db7619c4c1a58280d.setOption(option_ac45108173e8488db7619c4c1a58280d);
#         });
#     </script>

# %%
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType

# 投资人词云
# investors = {  s.split("&") for s in data["invest_name"] if not pd.isna(i)}
investors = {}
for s in data["invest_name"]:
    if not pd.isna(s):
        for i in s.split("&"):
            investors[i] = investors.get(i, 0) + 1


investors =  {v[0]:v[1] for v in sorted(investors.items(), key=lambda x : x[1], reverse=True)}

wc = (
    WordCloud()
    .add("投资人", [*investors.items()],  shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title="投资人词云"))
)

wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="45d69c5d381c4f369b3c2608570514aa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_45d69c5d381c4f369b3c2608570514aa = echarts.init(
#                     document.getElementById('45d69c5d381c4f369b3c2608570514aa'), 'white', {renderer: 'canvas'});
#                 var option_45d69c5d381c4f369b3c2608570514aa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u6295\u8d44\u4eba",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u5929\u4f7f\u6e7e",
#                     "value": 32,
#                     "textStyle": {
#                         "color": "rgb(18,57,108)"
#                     }
#                 },
#                 {
#                     "name": "\u771f\u683c\u57fa\u91d1",
#                     "value": 30,
#                     "textStyle": {
#                         "color": "rgb(132,124,103)"
#                     }
#                 },
#                 {
#                     "name": "\u9669\u5cf0\u957f\u9752",
#                     "value": 27,
#                     "textStyle": {
#                         "color": "rgb(70,25,111)"
#                     }
#                 },
#                 {
#                     "name": "IDG\u8d44\u672c",
#                     "value": 27,
#                     "textStyle": {
#                         "color": "rgb(103,63,115)"
#                     }
#                 },
#                 {
#                     "name": "\u521b\u65b0\u5de5\u573a",
#                     "value": 20,
#                     "textStyle": {
#                         "color": "rgb(147,151,135)"
#                     }
#                 },
#                 {
#                     "name": "\u7ecf\u7eac\u4e2d\u56fd",
#                     "value": 18,
#                     "textStyle": {
#                         "color": "rgb(125,75,72)"
#                     }
#                 },
#                 {
#                     "name": "\u7ea2\u6749\u8d44\u672c\u4e2d\u56fd",
#                     "value": 17,
#                     "textStyle": {
#                         "color": "rgb(99,123,7)"
#                     }
#                 },
#                 {
#                     "name": "PreAngel",
#                     "value": 17,
#                     "textStyle": {
#                         "color": "rgb(96,146,93)"
#                     }
#                 },
#                 {
#                     "name": "\u6885\u82b1\u521b\u6295",
#                     "value": 16,
#                     "textStyle": {
#                         "color": "rgb(34,38,68)"
#                     }
#                 },
#                 {
#                     "name": "\u6668\u5174\u8d44\u672c",
#                     "value": 12,
#                     "textStyle": {
#                         "color": "rgb(144,29,14)"
#                     }
#                 },
#                 {
#                     "name": "\u4e5d\u5408\u521b\u6295",
#                     "value": 12,
#                     "textStyle": {
#                         "color": "rgb(159,69,15)"
#                     }
#                 },
#                 {
#                     "name": "\u5947\u864e360",
#                     "value": 10,
#                     "textStyle": {
#                         "color": "rgb(39,101,140)"
#                     }
#                 },
#                 {
#                     "name": "\u9752\u677e\u57fa\u91d1",
#                     "value": 10,
#                     "textStyle": {
#                         "color": "rgb(20,151,133)"
#                     }
#                 },
#                 {
#                     "name": "\u6d2a\u6cf0\u57fa\u91d1",
#                     "value": 9,
#                     "textStyle": {
#                         "color": "rgb(6,58,40)"
#                     }
#                 },
#                 {
#                     "name": "\u6208\u58c1\u521b\u6295",
#                     "value": 9,
#                     "textStyle": {
#                         "color": "rgb(7,22,69)"
#                     }
#                 },
#                 {
#                     "name": "\u5fb7\u6c83\u57fa\u91d1",
#                     "value": 8,
#                     "textStyle": {
#                         "color": "rgb(87,84,120)"
#                     }
#                 },
#                 {
#                     "name": "\u817e\u8baf",
#                     "value": 8,
#                     "textStyle": {
#                         "color": "rgb(22,119,56)"
#                     }
#                 },
#                 {
#                     "name": "\u82f1\u8bfa\u5929\u4f7f\u57fa\u91d1",
#                     "value": 8,
#                     "textStyle": {
#                         "color": "rgb(65,30,127)"
#                     }
#                 },
#                 {
#                     "name": "\u5fb7\u8fc5\u6295\u8d44",
#                     "value": 7,
#                     "textStyle": {
#                         "color": "rgb(140,47,23)"
#                     }
#                 },
#                 {
#                     "name": "\u7b56\u6e90\u521b\u6295",
#                     "value": 7,
#                     "textStyle": {
#                         "color": "rgb(51,123,18)"
#                     }
#                 },
#                 {
#                     "name": "\u521b\u4e1a\u63a5\u529b\u5929\u4f7f",
#                     "value": 7,
#                     "textStyle": {
#                         "color": "rgb(73,148,7)"
#                     }
#                 },
#                 {
#                     "name": "\u91d1\u6c99\u6c5f\u521b\u6295",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(142,73,37)"
#                     }
#                 },
#                 {
#                     "name": "\u534e\u521b\u8d44\u672c",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(113,32,48)"
#                     }
#                 },
#                 {
#                     "name": "\u859b\u86ee\u5b50(\u86ee\u5b50\u57fa\u91d1)",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(127,51,42)"
#                     }
#                 },
#                 {
#                     "name": "\u8f6f\u94f6\u4e2d\u56fd",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(29,40,27)"
#                     }
#                 },
#                 {
#                     "name": "\u5e73\u5b89\u521b\u65b0\u6295\u8d44\u57fa\u91d1",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(69,45,100)"
#                     }
#                 },
#                 {
#                     "name": "\u8054\u60f3\u4e4b\u661f",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(44,84,144)"
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u8def\u8d44\u672c",
#                     "value": 6,
#                     "textStyle": {

# %%
# 倒闭词云
death_reasons = {}
for s in data["death_reason"]:
    if not pd.isna(s):
        for i in s.split():
            death_reasons[i] = death_reasons.get(i, 0) + 1

death_reasons = {i[0]:i[1] for i in sorted(death_reasons.items(), key= lambda x : x[1], reverse=True)}

wc = (
    WordCloud()
    .add("", [*death_reasons.items()][:10], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title="倒闭词云"))
)

wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="dd6c2bd1bbb1498b85de9185c2076e96" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_dd6c2bd1bbb1498b85de9185c2076e96 = echarts.init(
#                     document.getElementById('dd6c2bd1bbb1498b85de9185c2076e96'), 'white', {renderer: 'canvas'});
#                 var option_dd6c2bd1bbb1498b85de9185c2076e96 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u5546\u4e1a\u6a21\u5f0f\u532e\u4e4f",
#                     "value": 469,
#                     "textStyle": {
#                         "color": "rgb(112,139,48)"
#                     }
#                 },
#                 {
#                     "name": "\u884c\u4e1a\u7ade\u4e89",
#                     "value": 354,
#                     "textStyle": {
#                         "color": "rgb(76,105,129)"
#                     }
#                 },
#                 {
#                     "name": "\u5e02\u573a\u4f2a\u9700\u6c42",
#                     "value": 217,
#                     "textStyle": {
#                         "color": "rgb(146,61,71)"
#                     }
#                 },
#                 {
#                     "name": "\u4e1a\u52a1\u8c03\u6574",
#                     "value": 141,
#                     "textStyle": {
#                         "color": "rgb(58,87,160)"
#                     }
#                 },
#                 {
#                     "name": "\u73b0\u91d1\u6d41\u65ad\u88c2",
#                     "value": 116,
#                     "textStyle": {
#                         "color": "rgb(82,153,123)"
#                     }
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u5165\u573a\u65f6\u673a",
#                     "value": 113,
#                     "textStyle": {
#                         "color": "rgb(154,107,41)"
#                     }
#                 },
#                 {
#                     "name": "\u878d\u8d44\u80fd\u529b\u4e0d\u8db3",
#                     "value": 107,
#                     "textStyle": {
#                         "color": "rgb(160,58,139)"
#                     }
#                 },
#                 {
#                     "name": "\u653f\u7b56\u76d1\u7ba1",
#                     "value": 88,
#                     "textStyle": {
#                         "color": "rgb(12,43,50)"
#                     }
#                 },
#                 {
#                     "name": "\u70e7\u94b1",
#                     "value": 83,
#                     "textStyle": {
#                         "color": "rgb(155,99,127)"
#                     }
#                 },
#                 {
#                     "name": "\u6cd5\u5f8b\u6cd5\u89c4\u98ce\u9669",
#                     "value": 65,
#                     "textStyle": {
#                         "color": "rgb(13,19,121)"
#                     }
#                 }
#             ],
#             "drawOutOfBound": false,
#             "textStyle": {
#                 "emphasis": {}
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u5012\u95ed\u8bcd\u4e91",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_dd6c2bd1bbb1498b85de9185c2076e96.setOption(option_dd6c2bd1bbb1498b85de9185c2076e96);
#         });
#     </script>

# %%
import jieba

# ceo描述词云

des = {}

for s in data["ceo_per_des"].values:
    if not pd.isna(s):
        for word in jieba.lcut(s):
            if len(word) == 1:
                break
            des[word] = des.get(word, 0)+1

des = {i[0]:i[1] for i in sorted(des.items(), key= lambda x : x[1], reverse=True)}
# des

wc = (
    WordCloud()
    .add("", [*des.items()][:20])
    .set_global_opts(title_opts=opts.TitleOpts(title="CEO描述词云"))
)

wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="012bcb3a42724158ba8af742cc2b4398" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_012bcb3a42724158ba8af742cc2b4398 = echarts.init(
#                     document.getElementById('012bcb3a42724158ba8af742cc2b4398'), 'white', {renderer: 'canvas'});
#                 var option_012bcb3a42724158ba8af742cc2b4398 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u6709\u9650\u516c\u53f8",
#                     "value": 245,
#                     "textStyle": {
#                         "color": "rgb(118,1,93)"
#                     }
#                 },
#                 {
#                     "name": "\u79d1\u6280",
#                     "value": 125,
#                     "textStyle": {
#                         "color": "rgb(18,5,115)"
#                     }
#                 },
#                 {
#                     "name": "\u6267\u884c",
#                     "value": 100,
#                     "textStyle": {
#                         "color": "rgb(154,92,4)"
#                     }
#                 },
#                 {
#                     "name": "\u8463\u4e8b",
#                     "value": 100,
#                     "textStyle": {
#                         "color": "rgb(126,89,121)"
#                     }
#                 },
#                 {
#                     "name": "\u521b\u59cb\u4eba",
#                     "value": 95,
#                     "textStyle": {
#                         "color": "rgb(25,7,50)"
#                     }
#                 },
#                 {
#                     "name": "CEO",
#                     "value": 86,
#                     "textStyle": {
#                         "color": "rgb(29,61,158)"
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 72,
#                     "textStyle": {
#                         "color": "rgb(71,6,88)"
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 51,
#                     "textStyle": {
#                         "color": "rgb(21,42,151)"
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7edc\u79d1\u6280",
#                     "value": 41,
#                     "textStyle": {
#                         "color": "rgb(132,125,118)"
#                     }
#                 },
#                 {
#                     "name": "\u6df1\u5733\u5e02",
#                     "value": 30,
#                     "textStyle": {
#                         "color": "rgb(154,73,100)"
#                     }
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": 25,
#                     "textStyle": {
#                         "color": "rgb(112,91,68)"
#                     }
#                 },
#                 {
#                     "name": "\u8463\u4e8b\u957f",
#                     "value": 25,
#                     "textStyle": {
#                         "color": "rgb(118,110,135)"
#                     }
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": 24,
#                     "textStyle": {
#                         "color": "rgb(119,20,20)"
#                     }
#                 },
#                 {
#                     "name": "\u4fe1\u606f",
#                     "value": 22,
#                     "textStyle": {
#                         "color": "rgb(94,6,107)"
#                     }
#                 },
#                 {
#                     "name": "\u516c\u53f8",
#                     "value": 18,
#                     "textStyle": {
#                         "color": "rgb(45,157,47)"
#                     }
#                 },
#                 {
#                     "name": "\u6295\u8d44",
#                     "value": 18,
#                     "textStyle": {
#                         "color": "rgb(6,12,111)"
#                     }
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 17,
#                     "textStyle": {
#                         "color": "rgb(28,26,144)"
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7edc",
#                     "value": 17,
#                     "textStyle": {
#                         "color": "rgb(74,7,119)"
#                     }
#                 },
#                 {
#                     "name": "\u6bd5\u4e1a",
#                     "value": 14,
#                     "textStyle": {
#                         "color": "rgb(72,99,82)"
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": 14,
#                     "textStyle": {
#                         "color": "rgb(46,79,52)"
#                     }
#                 }
#             ],
#             "drawOutOfBound": false,
#             "textStyle": {
#                 "emphasis": {}
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "CEO\u63cf\u8ff0\u8bcd\u4e91",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_012bcb3a42724158ba8af742cc2b4398.setOption(option_012bcb3a42724158ba8af742cc2b4398);
#         });
#     </script>
